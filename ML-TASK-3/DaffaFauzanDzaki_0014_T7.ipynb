# %% [markdown]
# # 16 Classsification Task dengan Random Forest

# %% [markdown]
# ## General ML Model Training

# %% [markdown]
# ![image.png](attachment:a18373c6-cb4f-47f2-97ee-b9e36054ec7b.png)

# %% [markdown]
# ## Ensemble Learning: heterogeneous & homogeneous

# %% [markdown]
# ![image.png](attachment:f1d7ff08-ecf2-4e32-8804-ae2f1ddd1d1a.png)

# %% [markdown]
# ## Bagging: Boostrap Aggregating

# %% [markdown]
# ![image.png](attachment:588aacbf-1e44-46b5-8a24-2f7b12602777.png)

# %% [markdown]
# ## Random Forrest

# %% [markdown]
# ![image.png](attachment:bdd0b540-6c0c-4561-bd26-55e665efdca8.png)

# %% [markdown]
# ## Dataset

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'Class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# Class: {np.int64(0), np.int64(1), np.int64(2)}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
y,
test_size=0.3,
random_state=0)

# %% [markdown]
# ## Classification dengan RandomForestClassification

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100,
random_state=0)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ## Evaluasi Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
